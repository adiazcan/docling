# %%
import datetime
import logging
import time
from pathlib import Path

import pandas as pd

from docling.datamodel.base_models import InputFormat
from docling.datamodel.pipeline_options import PdfPipelineOptions
from docling.document_converter import DocumentConverter, PdfFormatOption
from docling.utils.export import generate_multimodal_pages
from docling.utils.utils import create_hash
# Out:
# /home/adiazcan/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
_log = logging.getLogger(__name__)
IMAGE_RESOLUTION_SCALE = 2.0

# %%
logging.basicConfig(level=logging.INFO)

input_doc_path = Path("./paciente.pdf")
output_dir = Path("scratch")

# Important: For operating with page images, we must keep them, otherwise the DocumentConverter
# will destroy them for cleaning up memory.
# This is done by setting AssembleOptions.images_scale, which also defines the scale of images.
# scale=1 correspond of a standard 72 DPI image
pipeline_options = PdfPipelineOptions()
pipeline_options.images_scale = IMAGE_RESOLUTION_SCALE
pipeline_options.generate_page_images = True

doc_converter = DocumentConverter(
    format_options={
        InputFormat.PDF: PdfFormatOption(pipeline_options=pipeline_options)
    }
)

start_time = time.time()

conv_res = doc_converter.convert(input_doc_path)

output_dir.mkdir(parents=True, exist_ok=True)

rows = []
for (
    content_text,
    content_md,
    content_dt,
    page_cells,
    page_segments,
    page,
) in generate_multimodal_pages(conv_res):

    dpi = page._default_image_scale * 72

    rows.append(
        {
            "document": conv_res.input.file.name,
            "hash": conv_res.input.document_hash,
            "page_hash": create_hash(
                conv_res.input.document_hash + ":" + str(page.page_no - 1)
            ),
            "image": {
                "width": page.image.width,
                "height": page.image.height,
                "bytes": page.image.tobytes(),
            },
            "cells": page_cells,
            "contents": content_text,
            "contents_md": content_md,
            "contents_dt": content_dt,
            "segments": page_segments,
            "extra": {
                "page_num": page.page_no + 1,
                "width_in_points": page.size.width,
                "height_in_points": page.size.height,
                "dpi": dpi,
            },
        }
    )

# Generate one parquet from all documents
df = pd.json_normalize(rows)
now = datetime.datetime.now()
output_filename = output_dir / f"multimodal_{now:%Y-%m-%d_%H%M%S}.parquet"
df.to_parquet(output_filename)

end_time = time.time() - start_time

_log.info(
    f"Document converted and multimodal pages generated in {end_time:.2f} seconds."
)
# Out:
# INFO:docling.document_converter:Going to convert document batch...
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# INFO:docling.pipeline.base_pipeline:Processing document paciente.pdf
# INFO:docling.document_converter:Finished converting document paciente.pdf in 99.36 sec.
# INFO:__main__:Document converted and multimodal pages generated in 99.96 seconds.

# %%
# This block demonstrates how the file can be opened with the HF datasets library
from datasets import Dataset
from PIL import Image
multimodal_df = pd.read_parquet(output_filename)

# Convert pandas DataFrame to Hugging Face Dataset and load bytes into image
dataset = Dataset.from_pandas(multimodal_df)
def transforms(examples):
    examples["image"] = Image.frombytes('RGB', (examples["image.width"], examples["image.height"]), examples["image.bytes"], 'raw')
    return examples
dataset = dataset.map(transforms)

print(multimodal_df)
# Out:
# Map:   0%|          | 0/23 [00:00<?, ? examples/s]
#         document                                               hash  \
# 0   paciente.pdf  2c4dfcf2d685d0801a894a1ef60b02ba055f43d9bd70e4...
# 1   paciente.pdf  2c4dfcf2d685d0801a894a1ef60b02ba055f43d9bd70e4...
# 16  02af16bdbe56f7102d10528189d4af922754fc84434160...
# 17  a4ce1ae1aa0c2b6bb64537eb952d7cbe969edf284c88c3...
# 18  72a6172fa2c59531cf26276b3c7544e392475c35dbe499...
# 19  6757139e198b78a8cb4585bdd7af3bb66d961adc733c3d...
# 20  db5353d54974642967c0921204e7eb809539a847a39a27...
# 21  ee7902fa29a09a0b9c70b2a956f2987440a07299d4a431...
# 22  7bcc70e2651141f3d713c8c907d741b982fbd70801561b...
#
#                                                 cells  \
# 0   [{'bbox': [0.060471678081171834, 0.93075327895...
# 1   [{'bbox': [0.2923133727690423, 0.0723688372379...
# 2   [{'bbox': [0.2923133727690423, 0.0723688372379...
# 3   [{'bbox': [0.2923133727690423, 0.0723688372379...
# 4   [{'bbox': [0.2923133727690423, 0.0723688372379...
# 5   [{'bbox': [0.2923133727690423, 0.0723688372379...
# 6   [{'bbox': [0.10949258859493988, 0.902069144290...
# 7   [{'bbox': [0.08345091575201713, 0.930753278951...
# 8   [{'bbox': [0.3153430035049552, 0.0723688372379...
# 9   [{'bbox': [0.3153430035049552, 0.0723688372379...
# 10  [{'bbox': [0.3153430035049552, 0.0723688372379...
# 11  [{'bbox': [0.3153430035049552, 0.0723688372379...
# 12  [{'bbox': [0.3153430035049552, 0.0723688372379...
# 13  [{'bbox': [0.3153430035049552, 0.0723688372379...
# 14  [{'bbox': [0.3153430035049552, 0.0723688372379...
# 15  [{'bbox': [0.3153430035049552, 0.0723688372379...
# 16  [{'bbox': [0.3153430035049552, 0.0723688372379...
# 17  [{'bbox': [0.10949258859493988, 0.902069144290...
# 18  [{'bbox': [0.03587986400793079, 0.930753278951...
# 19  [{'bbox': [0.10949258859493988, 0.902069144290...
# 20  [{'bbox': [0.27339889237454607, 0.102379878008...
# 21  [{'bbox': [0.27339889237454607, 0.102379878008...
# 22  [{'bbox': [0.03587986400793079, 0.930753278951...
#
#                                              contents  \
# 0   ATENDER AL PACIENTE EN PARADA CARDIORESPIRATOR...
# 1   Atender al paciente en parada cardiorespirator...
# 2   Atender al paciente en parada cardiorespirator...
# 3   7. DESCRIPCIÓN 7.1. RECURSOS HUMANOS -  Enfer...
# 4   Atender al paciente en parada cardiorespirator...
# 5   Atender al paciente en parada cardiorespirator...
# 6   ANEXO 1DIAGRAMA DE ACTIVACIÓN CODIGO PARADA VI...
# 7   ANEXO 2 SOPORTE VITAL BASICO ADULTOS Soporte v...
# 8   Atender al paciente en parada cardiorespirator...
# 9   Atender al paciente en parada cardiorespirator...
# 10  Atender al paciente en parada cardiorespirator...
# 11  Atender al paciente en parada cardiorespirator...
# 12  Atender al paciente en parada cardiorespirator...
# 13  1 1 m 8 6 ~ g 2 1 Comunicación prenatal Temper...
# 14  Atender al paciente en parada cardiorespirator...
# 15  Figura &: algoritmo de SVA Figura &: algoritmo...
# 16  Atender al paciente en parada cardiorespirator...
# 17  ANEXO 7 GUIA DE INTUBACIÓN Y FARMACOS EN PEDIA...
# 18  ANEXO 8. PREPARACIÓN MATERIAL CANALIZACIÓN UMB...
# 19  ANEXO 9 HOJA DE REGISTRO DE RCP INTRAHOSPITALA...
# 20  Atender al paciente en parada cardiorespirator...
# 21  Atender al paciente en parada cardiorespirator...
# 22  ANEXO 11. HOJA REGISTRO RCP NEONATAL INTRAHOSP...
#
#                                           contents_md  \
# 0   \n<!-- image -->\n\n## ATENDER AL PACIENTE EN ...
# 1   \n<!-- image -->\n\nAtender al paciente en par...
# 2   \n<!-- image -->\n\nAtender al paciente en par...
# 3   \n<!-- image -->\n\n## 7. DESCRIPCIÓN\n\n## 7....
# 4   \n<!-- image -->\n\nAtender al paciente en par...
# 5   \n<!-- image -->\n\nAtender al paciente en par...
# 6   \n<!-- image -->\n\n## ANEXO 1DIAGRAMA DE ACTI...
# 7   \n<!-- image -->\n\n## ANEXO 2 SOPORTE VITAL B...
# 8   \n<!-- image -->\n\nAtender al paciente en par...
# 9   \n<!-- image -->\n\nAtender al paciente en par...
# 10  \n<!-- image -->\n\nAtender al paciente en par...
# 11  \n<!-- image -->\n\nAtender al paciente en par...
# 12  \n<!-- image -->\n\n## Atender al paciente en ...
# 13  \n<!-- image -->\n\n\n<!-- image -->\n\n1 1 m ...
# 14  \n<!-- image -->\n\nAtender al paciente en par...
# 15  Figura &: algoritmo de SVA\n<!-- image -->\n\n...
# 16  \n<!-- image -->\n\nAtender al paciente en par...
# 17  \n<!-- image -->\n\n## ANEXO 7 GUIA DE INTUBAC...
# 18  \n<!-- image -->\n\n## ANEXO 8. PREPARACIÓN MA...
# 19  \n<!-- image -->\n\n## ANEXO 9 HOJA DE REGISTR...
# 20  \n<!-- image -->\n\nAtender al paciente en par...
# 21  \n<!-- image -->\n\nAtender al paciente en par...
# 22  \n<!-- image -->\n\n## ANEXO 11. HOJA REGISTRO...
#
#                                           contents_dt  \
# 0   <document>\n<figure>\n<location><loc_9><loc_91...
# 1   <document>\n<figure>\n<location><loc_6><loc_88...
# 2   <document>\n<figure>\n<location><loc_6><loc_88...
# 3   <document>\n<figure>\n<location><loc_6><loc_88...
# 4   <document>\n<figure>\n<location><loc_6><loc_88...
# 5   <document>\n<figure>\n<location><loc_6><loc_88...
# 6   <document>\n<figure>\n<location><loc_13><loc_8...
# 7   <document>\n<figure>\n<location><loc_11><loc_9...
# 8   <document>\n<figure>\n<location><loc_8><loc_88...
# 9   <document>\n<figure>\n<location><loc_8><loc_88...
# 10  <document>\n<figure>\n<location><loc_8><loc_88...
# 11  <document>\n<figure>\n<location><loc_8><loc_88...
# 12  <document>\n<figure>\n<location><loc_8><loc_88...
# 13  <document>\n<figure>\n<location><loc_8><loc_88...
# 14  <document>\n<figure>\n<location><loc_8><loc_88...
# 15  <document>\n<caption><location><loc_13><loc_20...
# 16  <document>\n<figure>\n<location><loc_8><loc_88...
# 17  <document>\n<figure>\n<location><loc_13><loc_8...
# 18  <document>\n<figure>\n<location><loc_6><loc_91...
# 19  <document>\n<figure>\n<location><loc_13><loc_8...
# 20  <document>\n<figure>\n<location><loc_11><loc_8...
# 21  <document>\n<figure>\n<location><loc_11><loc_8...
# 22  <document>\n<figure>\n<location><loc_6><loc_91...
#
#                                              segments  image.width  \
# 0   [{'bbox': [0.08845038581677991, 0.028850332078...         1191
# 1   [{'bbox': [0.0581698713916727, 0.0562920825534...         1191
# 2   [{'bbox': [0.058191869402073444, 0.05611729664...         1191
# 3   [{'bbox': [0.05821546936487739, 0.056094895627...         1191
# 4   [{'bbox': [0.058229540914787103, 0.05621103292...         1191
# 5   [{'bbox': [0.05826960894829595, 0.056087138642...         1191
# 6   [{'bbox': [0.12914339933440713, 0.040126011370...         1684
# 7   [{'bbox': [0.11207490975497254, 0.028817201775...         1191
# 8   [{'bbox': [0.0806307178807518, 0.0560086988432...         1191
# 9   [{'bbox': [0.0805487812192329, 0.0560186306846...         1191
# 10  [{'bbox': [0.08054491090222678, 0.055991517482...         1191
# 11  [{'bbox': [0.08061307077307814, 0.055992314929...         1191
# 12  [{'bbox': [0.08077587399191058, 0.056076046877...         1191
# 13  [{'bbox': [0.08074930080544629, 0.056219152389...         1191
# 14  [{'bbox': [0.08056801746369054, 0.056045091430...         1191
# 15  [{'bbox': [0.13102196976477598, 0.783922422023...         1191
# 16  [{'bbox': [0.08069606472318314, 0.056175292797...         1191
# 17  [{'bbox': [0.12917248803068113, 0.039997240028...         1684
# 18  [{'bbox': [0.063417534258457, 0.02903055512904...         1191
# 19  [{'bbox': [0.12930247191209987, 0.039930906383...         1684
# 20  [{'bbox': [0.10706260496397786, 0.078905767572...         1684
# 21  [{'bbox': [0.10722270153627464, 0.079451712951...         1684
# 22  [{'bbox': [0.06331070325659238, 0.028867585934...         1191
#
#     image.height                                        image.bytes  \
# 0           1684  b'\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff...
# 1           1684  b'\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff...
# 2           1684  b'\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff...
# 3           1684  b'\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff...
# 4           1684  b'\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff...
# 5           1684  b'\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff...
# 6           1191  b'\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff...
# 7           1684  b'\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff...
# 8           1684  b'\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff...
# 9           1684  b'\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff...
# 10          1684  b'\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff...
# 11          1684  b'\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff...
# 12          1684  b'\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff...
# 13          1684  b'\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff...
# 14          1684  b'\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff...
# 15          1684  b'\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff...
# 16          1684  b'\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff...
# 17          1191  b'\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff...
# 18          1684  b'\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff...
# 19          1191  b'\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff...
# 20          1191  b'\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff...
# 21          1191  b'\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff...
# 22          1684  b'\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff...
#
#     extra.page_num  extra.width_in_points  extra.height_in_points  extra.dpi
# 0                1             595.320007              841.920044      144.0
# 1                2             595.320007              841.920044      144.0
# 2                3             595.320007              841.920044      144.0
# 3                4             595.320007              841.920044      144.0
# 4                5             595.320007              841.920044      144.0
# 5                6             595.320007              841.920044      144.0
# 6                7             841.920044              595.320007      144.0
# 7                8             595.320007              841.920044      144.0
# 8                9             595.320007              841.920044      144.0
# 9               10             595.320007              841.920044      144.0
# 10              11             595.320007              841.920044      144.0
# 11              12             595.320007              841.920044      144.0
# 12              13             595.320007              841.920044      144.0
# 13              14             595.320007              841.920044      144.0
# 14              15             595.320007              841.920044      144.0
# 15              16             595.320007              841.920044      144.0
# 16              17             595.320007              841.920044      144.0
# 17              18             841.920044              595.320007      144.0
# 18              19             595.320007              841.920044      144.0
# 19              20             841.920044              595.320007      144.0
# 20              21             841.920044              595.320007      144.0
# 21              22             841.920044              595.320007      144.0
# 22              23             595.320007              841.920044      144.0
